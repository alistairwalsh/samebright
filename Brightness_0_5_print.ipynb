# %% [markdown]
# ### Do file walk and create list of '.png' files (I didn't have '.tif' files handy but it will work the same)

# %%
import os
import os.path

file_list = []
for dirpath, dirnames, filenames in os.walk("/Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report"):
    for filename in [f for f in filenames if f.endswith(".png")]:
        file_list.append(os.path.join(dirpath, filename))

for item in file_list:
    print item
# Out:
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/easyPulseMeter/Circuit_StageI.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/easyPulseMeter/easyPulseMeterfinger.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/LCDshield/lcd-shield-front-001_large.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/PulseSensor/PulseSensor_files/Screen_Shot_2012-09-24_at_2.24.20_PM_small.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/T34/polarheart-2.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/T34_files/Bandeau-LTW-620x120-UK.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/T34_files/btn-ok.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/T34_files/nordictrack.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/T34_files/pictos-specifications_0.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images/T34_files/small banner OFFERS.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1/Freetronics-LeoStick-web-label-002-centre_large.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1/Gray940_-_sweat_gland.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1/GSR_INA333_WEB_small.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1/Skin.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1/Truth_Circuit.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1a/builder.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1a/coder.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1a/custom_code.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1a/ipy_serial.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1a/pyserial.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images1a/serialCode.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images2/column_board_v2.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images2/SinusRhythmLabels.png
# /Users/Wintermute/Dropbox/DSTO RA/DSTO_Final/just_report/graphics/images_ch4/Oxy_and_Deoxy_Hemoglobin_Near-Infrared_absorption_spectra.png

# %% [markdown]
# ### Create a '.csv' file called 'brightness' to save the file name and a value.

# %%
from PIL import Image
import csv
#create a fake brightness value for now
brightness = 255/2
#setup a .csv file to write to
with open('brightness.csv', 'wb') as csvfile:
    # create a file name variable so later when there is a list of files, it can iterate over the list 
    for item in file_list:
        fname =  item
    # Load the image into imag
        imag = Image.open(fname)
    ## Show me the image
        imag.show()
        #write the file_name to .csv and add brightness value
        brightness_writer = csv.writer(csvfile, delimiter=',',quotechar='"', quoting=csv.QUOTE_MINIMAL)
        brightness_writer.writerow([item] + [brightness])

# %% [markdown]
# ### Look at the values in the file that was created (fake brightness values)

# %%
with open('brightness.csv', 'r') as csvfile:
    for line in csvfile:
        line = line[line.rfind('/')+1:] # this gets rid of the directories to only show the file name
        print line
# Out:
# Circuit_StageI.png,127
#
# easyPulseMeterfinger.png,127
#
# lcd-shield-front-001_large.png,127
#
# Screen_Shot_2012-09-24_at_2.24.20_PM_small.png,127
#
# polarheart-2.png,127
#
# Bandeau-LTW-620x120-UK.png,127
#
# btn-ok.png,127
#
# nordictrack.png,127
#
# pictos-specifications_0.png,127
#
# small banner OFFERS.png,127
#
# Freetronics-LeoStick-web-label-002-centre_large.png,127
#
# Gray940_-_sweat_gland.png,127
#
# GSR_INA333_WEB_small.png,127
#
# Skin.png,127
#
# Truth_Circuit.png,127
#
# builder.png,127
#
# coder.png,127
#
# custom_code.png,127
#
# ipy_serial.png,127
#
# pyserial.png,127
#
# serialCode.png,127
#
# column_board_v2.png,127
#
# SinusRhythmLabels.png,127
#
# Oxy_and_Deoxy_Hemoglobin_Near-Infrared_absorption_spectra.png,127

# %% [markdown]
# ### Current bit I'm working on - take the pixel values from just one image

# %%
# %matplotlib inline #to show image in the notebook

# %% [markdown]
# ### This is the image I'm using

# %%
import matplotlib.image as mpimg
imgplot = plt.imshow(imag)

# %%
colMap = list(imag.getdata())

# %% [markdown]
# #### Calculate the overall average brightness.

# %%
value_list = []
for triple in colMap:
    value_list.append(sum(triple)/len(triple))
print sum(value_list)/len(value_list)
# Out:
# 244

# %% [markdown]
# #### Slightly more advanced - Calculate the brightness in each channel and plot histogram for each channel

# %%
import matplotlib.pyplot as plt
import numpy as np

value_list_r = []
value_list_g = []
value_list_b = []

for r,g,b in colMap:
    value_list_r.append(r)
    value_list_g.append(g)
    value_list_b.append(b)

plt.hist(value_list_r,color='red')
print 'red',sum(value_list_r)/len(value_list_r)
# Out:
# red 245

# %%
plt.hist(value_list_g,color='green')
print 'green',sum(value_list_g)/len(value_list_g)
# Out:
# green 241

# %%
plt.hist(value_list_b,color='blue')
print 'blue', sum(value_list_b)/len(value_list_b)
# Out:
# blue 245

# %% [markdown]
# ### Next bit would be:
#
# Use the file walk, create csv file and calculate a value to create a file with name and value.
#
#
# Then:
#
# the fancier methods of calculation

# %%
#Standard
LuminanceA = (0.2126*R) + (0.7152*G) + (0.0722*B)
#Percieved A
LuminanceB = (0.299*R + 0.587*G + 0.114*B)
#Perceived B, slower to calculate
LuminanceC = sqrt( 0.241*R**2 + 0.691*G**2 + 0.068*B**2 )

# %% [markdown]
# #### This is what I've done so far this morning, it's looking pretty good. I can search a file structure for files with a particular extension and create a list of those files. I can create a data file to store the file name and a calculated value.
# I can read the pixel values from an image and get an average brightness or three brightness values for the individual channels.
# One last thing to do is take that brightness information and write it to the data file.
